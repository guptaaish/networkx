# %%
import pandas as pd
import numpy as np

# %%
A,B,C,D,E = [1.55,2.45,3.45,3.78,8.28]

# %%
df = pd.DataFrame(data = {'A' : A,'B' : B,'C' : C,'D' : D,'E' : E},index = [i for i in range(0,5)])

# %%
df
# Out:
#       A     B     C     D     E
# 0  1.55  2.45  3.45  3.78  8.28
# 1  1.55  2.45  3.45  3.78  8.28
# 2  1.55  2.45  3.45  3.78  8.28
# 3  1.55  2.45  3.45  3.78  8.28
# 4  1.55  2.45  3.45  3.78  8.28

# %%
df.groupby(['C','D','E']).sum()
# Out:
#                    A      B
# C    D    E
# 3.45 3.78 8.28  7.75  12.25

# %%
no_of = [1]*5

# %%
df['No_of_cases'] = no_of

# %%
df
# Out:
#       A     B     C     D     E  No_of_cases
# 0  1.55  2.45  3.45  3.78  8.28            1
# 1  1.55  2.45  3.45  3.78  8.28            1
# 2  1.55  2.45  3.45  3.78  8.28            1
# 3  1.55  2.45  3.45  3.78  8.28            1
# 4  1.55  2.45  3.45  3.78  8.28            1

# %%
df[['C','D','E']] = df[['C','D','E']].apply(round)

# %%
df
# Out:
#       A     B    C    D    E  No_of_cases
# 0  1.55  2.45  3.0  4.0  8.0            1
# 1  1.55  2.45  3.0  4.0  8.0            1
# 2  1.55  2.45  3.0  4.0  8.0            1
# 3  1.55  2.45  3.0  4.0  8.0            1
# 4  1.55  2.45  3.0  4.0  8.0            1

# %%
new_df = df.iloc[:,2:]

# %%
grouped_df = new_df.groupby(['C','D','E']).sum().reset_index()

# %%
df.iloc[:,:-1].join(grouped_df,lsuffix='', rsuffix='_other')
# Out:
#       A     B    C    D    E  C_other  D_other  E_other  No_of_cases
# 0  1.55  2.45  3.0  4.0  8.0      3.0      4.0      8.0          5.0
# 1  1.55  2.45  3.0  4.0  8.0      NaN      NaN      NaN          NaN
# 2  1.55  2.45  3.0  4.0  8.0      NaN      NaN      NaN          NaN
# 3  1.55  2.45  3.0  4.0  8.0      NaN      NaN      NaN          NaN
# 4  1.55  2.45  3.0  4.0  8.0      NaN      NaN      NaN          NaN

# %%
df.iloc[:,:-1].merge(grouped_df, left_on=['C','D','E'], right_on=['C','D','E'])
# Out:
#       A     B    C    D    E  No_of_cases
# 0  1.55  2.45  3.0  4.0  8.0            5
# 1  1.55  2.45  3.0  4.0  8.0            5
# 2  1.55  2.45  3.0  4.0  8.0            5
# 3  1.55  2.45  3.0  4.0  8.0            5
# 4  1.55  2.45  3.0  4.0  8.0            5
